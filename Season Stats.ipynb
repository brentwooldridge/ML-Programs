# %%
import pandas as pd

# %%
season = pd.read_csv("Seasons_Stats.csv")

# %%
season.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
season.shape
# Out:
# (24691, 53)

# %%
season.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
season.rename({"Tm":"Team", "Unnamed: 0":"Remove Later", "Year":"Rookie Year"})
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN
# 5               5  1950.0         Ed Bartels    F  24.0  NYK   2.0   NaN
# 6               6  1950.0        Ralph Beard    G  22.0  INO  60.0   NaN
# 7               7  1950.0         Gene Berce  G-F  23.0  TRI   3.0   NaN
# 8               8  1950.0      Charlie Black  F-C  28.0  TOT  65.0   NaN
# 9               9  1950.0      Charlie Black  F-C  28.0  FTW  36.0   NaN
# 10             10  1950.0      Charlie Black  F-C  28.0  AND  29.0   NaN
# 11             11  1950.0        Nelson Bobb   PG  25.0  PHW  57.0   NaN
# ...

# %%
"""
for i in ['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
       'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
       'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
       'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
       '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
       'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']:
    for j in range(24690):
        if pd.isnull(season[i][j])== True:
            season[i][j] = "--"
            """
# Out:
# '\nfor i in [\'Unnamed: 0\', \'Year\', \'Player\', \'Pos\', \'Age\', \'Tm\', \'G\', \'GS\', \'MP\',\n       \'PER\', \'TS%\', \'3PAr\', \'FTr\', \'ORB%\', \'DRB%\', \'TRB%\', \'AST%\', \'STL%\',\n       \'BLK%\', \'TOV%\', \'USG%\', \'blanl\', \'OWS\', \'DWS\', \'WS\', \'WS/48\', \'blank2\',\n       \'OBPM\', \'DBPM\', \'BPM\', \'VORP\', \'FG\', \'FGA\', \'FG%\', \'3P\', \'3PA\', \'3P%\',\n       \'2P\', \'2PA\', \'2P%\', \'eFG%\', \'FT\', \'FTA\', \'FT%\', \'ORB\', \'DRB\', \'TRB\',\n       \'AST\', \'STL\', \'BLK\', \'TOV\', \'PF\', \'PTS\']:\n    for j in range(24690):\n        if pd.isnull(season[i][j])== True:\n            season[i][j] = "--"\n            '

# %%
season.head(1000)
# Out:
#      Unnamed: 0    Year            Player  Pos   Age   Tm     G  GS      MP  \
# 0             0  1950.0   Curly Armstrong  G-F  31.0  FTW  63.0 NaN     NaN
# 1             1  1950.0      Cliff Barker   SG  29.0  INO  49.0 NaN     NaN
# 2             2  1950.0     Leo Barnhorst   SF  25.0  CHS  67.0 NaN     NaN
# 3             3  1950.0        Ed Bartels    F  24.0  TOT  15.0 NaN     NaN
# 4             4  1950.0        Ed Bartels    F  24.0  DNN  13.0 NaN     NaN
# 5             5  1950.0        Ed Bartels    F  24.0  NYK   2.0 NaN     NaN
# 6             6  1950.0       Ralph Beard    G  22.0  INO  60.0 NaN     NaN
# 7             7  1950.0        Gene Berce  G-F  23.0  TRI   3.0 NaN     NaN
# 8             8  1950.0     Charlie Black  F-C  28.0  TOT  65.0 NaN     NaN
# 9             9  1950.0     Charlie Black  F-C  28.0  FTW  36.0 NaN     NaN
# 10           10  1950.0     Charlie Black  F-C  28.0  AND  29.0 NaN     NaN
# ...

# %%
import colorama

# %%
print(season.describe())
# Out:
#          Unnamed: 0          Year           Age             G            GS  \
# count  24691.000000  24624.000000  24616.000000  24624.000000  18233.000000
# mean   12345.000000   1992.594989     26.664405     50.837110     23.593375
# std     7127.822084     17.429594      3.841892     26.496161     28.632387
# min        0.000000   1950.000000     18.000000      1.000000      0.000000
# 25%     6172.500000   1981.000000     24.000000     27.000000      0.000000
# 50%    12345.000000   1996.000000     26.000000     58.000000      8.000000
# 75%    18517.500000   2007.000000     29.000000     75.000000     45.000000
# max    24690.000000   2017.000000     44.000000     88.000000     83.000000
#
#                  MP           PER           TS%          3PAr           FTr  \
# count  24138.000000  24101.000000  24538.000000  18839.000000  24525.000000
# mean    1209.720317     12.479071      0.493001      0.158604      0.325455
# ...

# %%
print(max(season['Player']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-cfcbfb0fe373> in <module>()
# ----> 1 print(max(season['Player']))
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
season.loc[season['G'] == max(season['G'])]
# Out:
#       Unnamed: 0    Year         Player Pos   Age   Tm     G  GS      MP  \
# 2676        2676  1969.0  Walt Bellamy*   C  29.0  TOT  88.0 NaN  3159.0
#
#        PER   ...      FT%  ORB  DRB     TRB    AST  STL  BLK  TOV     PF  \
# 2676  18.0   ...    0.649  NaN  NaN  1101.0  176.0  NaN  NaN  NaN  320.0
#
#          PTS
# 2676  1527.0
#
# [1 rows x 53 columns]

# %%
for i in ['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
       'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
       'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
       'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
       '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
       'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']:
    if type(season[i])!= (str or NaN):
        season.loc[season[i] == max(season[i])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-64b945f59095> in <module>()
#       6        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']:
#       7     if type(season[i])!= (str or NaN):
# ----> 8         season.loc[season[i] == max(season[i])]
#       9
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
len(season.columns)
# Out:
# 53

# %%
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# ...
